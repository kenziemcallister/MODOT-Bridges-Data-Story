# %%
import geoplot as gplt 
import geopandas as gpd 
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import mapclassify as mc
import geoplot.crs as gcrs
import numpy as np
import seaborn as sns

# %%
#loading primary dataset 

bridge_points = gpd.read_file("../GennyPlots/ShapeFilesFile/NBI/National_Bridge_Inventory.shp")
pd.set_option('display.max_columns', None)
bridge_points.head()
# Out:
#   STATE_CODE STRUCTURE_ RECORD_TYP ROUTE_PREF SERVICE_LE ROUTE_NUMB  \
# 0         29          1          1          3          1      00006
# 1         29         10          1          2          1      00036
# 2         29        100          1          1          1      00029
# 3         29       1000          1          2          1      00060
# 4         29      10000          1          3          1      00076
#
#   DIRECTION_ HIGHWAY_DI COUNTY_COD PLACE_CODE    FEATURES_D  CRITICAL_F  \
# 0          0         01        021      64550         IS 29         0.0
# 1          0         01        025      27784  LIT OTTER CR         0.0
# 2          0         03        165      29026        OWL CR         0.0
# 3          0         06        077      70000     JAMES RVR         0.0
# 4          0         07        067      45272     CLEVER CR         0.0
#
#   FACILITY_C          LOCATION_0  MIN_VERT_C  KILOPOINT_ BASE_HWY_N  \
# 0     MO 6 E   S 2 T 57 N R 35 W       99.99       0.793          1
# 1    US 36 E  S 21 T 57 N R 27 W       99.99      80.150          1
# 2    IS 29 S  S 25 T 54 N R 35 W       99.99     157.835          1
# 3    US 60 E  S 15 T 28 N R 21 W       99.99     141.811          1
# 4    MO 76 E   S 1 T 26 N R 14 W       99.99     291.470          0
#
#    LRS_INV_RO SUBROUTE_N   LAT_016   LONG_017  DETOUR_KIL TOLL_020 MAINTENANC  \
# 0  0000003556          0  39463723  094473709          10        3         01
# 1  0000003560          0  39440616  093562572           1        3         01
# 2  0000005878          0  39273317  094471789           1        3         01
# 3  0000007782          0  37072768  093133368           1        3         01
# 4        None       None  36581862  092254722          48        3         01
#
#   OWNER_022 FUNCTIONAL  YEAR_BUILT TRAFFIC_LA TRAFFIC__1  ADT_029  YEAR_ADT_0  \
# 0        01         14        1958          6          4    15423        2023
# 1        01         02        1958          4          0     8566        2023
# 2        01         01        1958          4          0    36821        2023
# 3        01         12        1965          2          0    15996        2023
# 4        01         07        1940          2          0      419        2023
#
#   DESIGN_LOA  APPR_WIDTH MEDIAN_COD  DEGREES_SK STRUCTURE1 RAILINGS_0  \
# 0          4        25.0          0           7          0          1
# 1          4        24.7          2           0          0          N
# 2          5        34.1          2          30          0          1
# 3          4        15.2          1          20          0          1
# 4          0         7.3          0           0          0          0
#
#   TRANSITION APPR_RAIL_ APPR_RAIL1 HISTORY_03 NAVIGATION  NAV_VERT_C  \
# 0          0          0          0          5          N         0.0
# 1          N          N          N          5          0         0.0
# 2          1          1          1          5          0         0.0
# 3          1          1          1          5          0         0.0
# 4          0          0          0          5          0         0.0
#
#    NAV_HORR_C OPEN_CLOSE SERVICE_ON SERVICE_UN STRUCTUR_1 STRUCTUR_2  \
# 0         0.0          A          5          1          4         02
# 1         0.0          A          1          5          2         19
# 2         0.0          A          1          5          2         19
# 3         0.0          P          1          5          4         02
# 4         0.0          A          1          5          2         01
#
#   APPR_KIND_ APPR_TYPE_  MAIN_UNIT_  APPR_SPANS  HORR_CLR_M  MAX_SPAN_L  \
# 0          0         00           4           0        23.8        17.1
# 1          0         00           2           0        24.7         3.0
# 2          0         00           2           0        30.4         2.7
# 3          0         00           3           0        15.2        45.7
# 4          0         00           5           0         6.7         3.2
#
#    STRUCTUR_3  LEFT_CURB_  RIGHT_CURB  ROADWAY_WI  DECK_WIDTH  VERT_CLR_O  \
# 0        61.6         1.5         1.5        23.8        28.5       99.99
# 1         6.4         0.0         0.0         0.0         0.0       99.99
# 2         6.6         0.0         0.0         0.0         0.0       99.99
# 3       120.4         0.2         0.2        15.2        16.1       99.99
# 4        15.5         0.0         0.0         6.7         7.2       99.99
#
#   VERT_CLR_U  VERT_CLR_1 LAT_UND_RE  LAT_UND_MT  LEFT_LAT_U DECK_COND_  \
# 0          H        4.83          H         3.4         5.7          6
# 1          N        0.00          N         0.0         0.0          N
# 2          N        0.00          N         0.0         0.0          N
# 3          N        0.00          N         0.0         0.0          7
# 4          N        0.00          N         0.0         0.0          5
#
#   SUPERSTRUC SUBSTRUCTU CHANNEL_CO CULVERT_CO OPR_RATING  OPERATING_  \
# 0          7          7          N          N          1        58.5
# 1          N          N          6          5          0        72.0
# 2          N          N          7          4          0        99.9
# 3          5          6          8          N          1        45.9
# 4          5          5          6          N          1        26.1
#
#   INV_RATING  INVENTORY_ STRUCTURAL DECK_GEOME UNDCLRENCE POSTING_EV  \
# 0          1        35.1          7          5          5          5
# 1          0        43.2          5          N          N          5
# 2          0        99.9          4          N          N          5
# 3          1        27.9          5          9          N          5
# 4          1        16.2          5          4          N          5
#
#   WATERWAY_E APPR_ROAD_ WORK_PROPO WORK_DONE_  IMP_LEN_MT DATE_OF_IN  \
# 0          N          8       None       None         0.0        722
# 1          8          8       None       None         0.0       1222
# 2          8          8         35          1         1.3       1222
# 3          8          8       None       None         0.0        722
# 4          4          6       None       None         0.0        223
#
#    INSPECT_FR FRACTURE_0 UNDWATER_L SPEC_INSPE FRACTURE_L UNDWATER_1  \
# 0          24          N          N          N       None       None
# 1          24          N          N          N       None       None
# 2          24          N          N          N       None       None
# 3          24          N          N          N       None       None
# 4          24          N          N          N       None       None
#
#   SPEC_LAST_  BRIDGE_IMP  ROADWAY_IM  TOTAL_IMP_  YEAR_OF_IM OTHER_STAT  \
# 0       None           0           0           0           0       None
# 1       None           0           0           0           0       None
# 2       None         204          20         306        2024       None
# 3       None           0           0           0           0       None
# 4       None           0           0           0           0       None
#
#   OTHER_ST_1 OTHR_STATE STRAHNET_H PARALLEL_S TRAFFIC_DI TEMP_STRUC  \
# 0       None       None          0          N          2       None
# 1       None       None          0          N          2       None
# 2       None       None          1          N          2       None
# 3       None       None          2          R          1       None
# 4       None       None          0          N          2       None
#
#   HIGHWAY_SY FEDERAL_LA  YEAR_RECON DECK_STRUC SURFACE_TY MEMBRANE_T  \
# 0          1          0        1992          1          1          0
# 1          1          0        2000          N          N          N
# 2          1          0           0          N          N          N
# 3          1          0        2009          1          4          0
# 4          0          0           0          1          6          0
#
#   DECK_PROTE  PERCENT_AD NATIONAL_N PIER_PROTE BRIDGE_LEN SCOUR_CRIT  \
# 0          1           5          0       None          Y          N
# 1          N          41          1       None          Y          8
# 2          N          25          1       None          Y          8
# 3          0          12          1       None          Y          8
# 4          0          12          0       None          Y          8
#
#    FUTURE_ADT  YEAR_OF_FU  MIN_NAV_CL FED_AGENCY SUBMITTED_ BRIDGE_CON  \
# 0       20821        2043         0.0          N         29          F
# 1       17989        2043         0.0          N         29          F
# 2       75483        2043         0.0          N         29          P
# 3       24794        2043         0.0          N         29          F
# 4         649        2043         0.0          N         29          F
#
#    LOWEST_RAT  DECK_AREA STATUS  DATE      LATDD     LONGDD  \
# 0           6    1755.60     AM  1202  39.776933 -94.793517
# 1           5     158.08     AM  1202  39.735267 -93.940350
# 2           4     225.06     AM  0303  39.466333 -94.787725
# 3           5    1938.44     AM  0303  37.124864 -93.226503
# 4           5     111.60     AM  1202  36.972156 -92.429808
#
#                      geometry
# 0  POINT (-94.79352 39.77693)
# 1  POINT (-93.94035 39.73527)
# 2  POINT (-94.78773 39.46633)
# 3   POINT (-93.2265 37.12486)
# 4  POINT (-92.42981 36.97216)

# %%
#loading in contextualizing data, county line polygons, MODOT District polygons, and MODOT maintained roads lines

county_bounds = gpd.read_file("../GennyPlots/ShapeFilesFile/MO_County_Boundaries/MO_County_Boundaries.shp")
county_bounds.to_crs(crs=None, epsg=4326, inplace=True)
districts = gpd.read_file("../GennyPlots/ShapeFilesFile/MO_MoDOT_Districts/MO_MoDOT_Districts.shp")
districts.to_crs(crs=None, epsg=4326, inplace=True)
roads = gpd.read_file("../GennyPlots/ShapeFilesFile/MO_MoDOT_Roads_Arcs/MO_MoDOT_Roads_Arcs.shp")
roads.to_crs(crs=None, epsg=4326, inplace=True)
# Out:
# /opt/conda/lib/python3.11/site-packages/pyogrio/geopandas.py:49: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   res = pd.to_datetime(ser, **datetime_kwargs)

# %%
proj = gcrs.AlbersEqualArea(central_latitude=39.5055, central_longitude=-91.5238)

fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(30, 16), subplot_kw={'projection': proj})
plt.tight_layout()

#adding in county lines at a low alpha to help orient viewer, but not overwhelm
gplt.polyplot(
    county_bounds,
    linewidth=.5,
    projection=proj,
    facecolor="none",
    edgecolor='black',
    alpha=0.5,
    ax=ax1
)

#adding in MODOT districts to aid in contextualizing analysis
gplt.polyplot(
    districts,
    linewidth=1,
    projection=proj,
    facecolor="none",
    edgecolor='black',
    alpha=1,
    ax=ax1,
)

#plotting each bridgepoints
gplt.pointplot(bridge_points.geometry,
               color="lightgrey", 
               s=.7, 
               ax=ax1, 
               alpha = .4,
               extent= districts.buffer(.1).total_bounds)


gplt.pointplot(bridge_points[(bridge_points["YEAR_OF_IM"]!=0)&(bridge_points["BRIDGE_CON"]=="G")].geometry,
               color='green',
               s=5, 
               edgecolor='blue',
               linewidths=1,
               marker = 'o',
               ax=ax1, 
               alpha = 1,
               label = "Improvement - Good - 70",
               extent= districts.buffer(.1).total_bounds)
gplt.pointplot(bridge_points[(bridge_points["YEAR_OF_IM"]!=0)&(bridge_points["BRIDGE_CON"]=="F")].geometry,
               color='orange',
               s=5, 
               edgecolor='blue',
               linewidths=1,
               marker = 'o',
               ax=ax1, 
               alpha = 1,
               label = "Improvement - Fair - 752",
               extent= districts.buffer(.1).total_bounds)
gplt.pointplot(bridge_points[(bridge_points["BRIDGE_CON"]=="P")&(bridge_points["YEAR_OF_IM"]!=0)].geometry,
               color="red", 
               s=5, 
               edgecolor='blue',
               linewidths=1,
               marker = 'o',
               ax=ax1, 
               alpha = 1,
               label = "Improvement - Poor - 706",
               extent= districts.buffer(.1).total_bounds)

ax1.legend(fontsize=20)

gplt.polyplot(
    county_bounds,
    linewidth=.5,
    projection=proj,
    facecolor="none",
    edgecolor='black',
    alpha=0.5,
    ax=ax2,
)

#adding in MODOT districts to aid in contextualizing analysis
gplt.polyplot(
    districts,
    linewidth=1,
    projection=proj,
    facecolor="none",
    edgecolor='black',
    alpha=1,
    ax=ax2,
)

#plotting each bridgepoints
gplt.pointplot(bridge_points[bridge_points["YEAR_OF_IM"]==0].geometry,
               color="lightgrey", 
               s=1, 
               ax=ax2, 
               alpha = .5,
               extent= districts.buffer(.1).total_bounds)
gplt.pointplot(bridge_points[(bridge_points["YEAR_OF_IM"]!=0)].geometry,
               color='lightgrey',
               s=1, 
               marker = 'o',
               ax=ax2, 
               alpha = .5,
               #label = "Total Improvements - 1,528",
               extent= districts.buffer(.1).total_bounds)
gplt.pointplot(bridge_points[(bridge_points["LOWEST_RAT"]==2)&(bridge_points["YEAR_OF_IM"]==0)].geometry,
               color="red", 
               s=14, 
               marker = 'x',
               linewidths=4,
               ax=ax2, 
               alpha = 1,
               label = "Level 2 - No Improv. - 1",
               extent= districts.buffer(.1).total_bounds)
gplt.pointplot(bridge_points[(bridge_points["LOWEST_RAT"]==3)&(bridge_points["YEAR_OF_IM"]==0)].geometry,
               color="red", 
               s=11, 
               marker = '+',
               ax=ax2, 
               alpha = 1,
               label = "Level 3 - No Improv. - 13",
               extent= districts.buffer(.1).total_bounds)
gplt.pointplot(bridge_points[(bridge_points["LOWEST_RAT"]==4)&(bridge_points["YEAR_OF_IM"]==0)].geometry,
               color="red", 
               s=6, 
               marker = 'x',
               ax=ax2, 
               alpha = 1,
               label = "Level 4 - No Improv. - 29",
               extent= districts.buffer(.1).total_bounds)


ax2.legend(fontsize=20)
ax1.set_title("MoDOT Map of Bridge Improvements",fontsize=20)
ax2.set_title("Remaining Poor MoDOT Bridges without Improvement", fontsize=20)
fig.suptitle("MoDOT Bridges and Improvements", fontsize=30);
fig.savefig("fig9.png")
# Out:
# /tmp/ipykernel_182/892908526.py:34: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   extent= districts.buffer(.1).total_bounds)
# /tmp/ipykernel_182/892908526.py:46: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   extent= districts.buffer(.1).total_bounds)
# /tmp/ipykernel_182/892908526.py:56: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   extent= districts.buffer(.1).total_bounds)
# /tmp/ipykernel_182/892908526.py:66: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   extent= districts.buffer(.1).total_bounds)
# /tmp/ipykernel_182/892908526.py:97: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   extent= districts.buffer(.1).total_bounds)
# /tmp/ipykernel_182/892908526.py:105: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   extent= districts.buffer(.1).total_bounds)
# /tmp/ipykernel_182/892908526.py:114: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   extent= districts.buffer(.1).total_bounds)
# /tmp/ipykernel_182/892908526.py:122: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   extent= districts.buffer(.1).total_bounds)
# /tmp/ipykernel_182/892908526.py:130: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   extent= districts.buffer(.1).total_bounds)
